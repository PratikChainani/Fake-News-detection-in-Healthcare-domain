# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import f1_score, precision_score,accuracy_score
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

# %%
from google.colab import drive
drive.mount('/content/drive')
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid data/data/finalprob.csv')

#val = pd.read_csv('data/postproc_val.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid data/data/finalprobtest.csv')
# Out:
# Mounted at /content/drive

# %%
pd.options.display.max_rows=None
train
# Out:
#       class0_pred  class1_pred  username_real  ...  domain_real  domain_fake  label
# 0        0.554285     0.445715       0.000000  ...     0.000000     0.000000      0
# 1        0.953478     0.046522       0.000000  ...     0.838903     0.161097      0
# 2        0.124017     0.875983       0.000000  ...     0.000000     1.000000      1
# 3        0.950679     0.049321       0.995146  ...     0.838903     0.161097      0
# 4        0.941731     0.058269       0.000000  ...     0.838903     0.161097      0
# 5        0.905005     0.094995       0.000000  ...     1.000000     0.000000      0
# 6        0.933001     0.066999       0.000000  ...     0.994819     0.005181      0
# 7        0.044262     0.955738       0.000000  ...     0.000000     1.000000      1
# 8        0.304175     0.695825       0.000000  ...     0.000000     0.000000      1
# 9        0.299199     0.700801       0.000000  ...     0.500000     0.500000      1
# ...

# %%
train.head()
# Out:
#    class0_pred  class1_pred  username_real  ...  domain_real  domain_fake  label
# 0     0.554285     0.445715       0.000000  ...     0.000000     0.000000      0
# 1     0.953478     0.046522       0.000000  ...     0.838903     0.161097      0
# 2     0.124017     0.875983       0.000000  ...     0.000000     1.000000      1
# 3     0.950679     0.049321       0.995146  ...     0.838903     0.161097      0
# 4     0.941731     0.058269       0.000000  ...     0.838903     0.161097      0
#
# [5 rows x 7 columns]

# %%
train.fillna(0,inplace=True)
test.fillna(0,inplace=True)
train_X = train.iloc[:, :-1].values
train_y = train.iloc[:, -1].values
#val_X = val.iloc[:, :-1].values
#val_y = val.iloc[:, -1].values
test_X = test.iloc[:, :-1].values
test_y = test.iloc[:, -1].values
print(train_X)
print(test_X)
# Out:
# [[0.5542853  0.4457147  0.         0.         0.         0.        ]
#  [0.95347817 0.04652183 0.         0.         0.83890317 0.16109683]
#  [0.12401743 0.87598257 0.         0.         0.         1.        ]
#  ...
#  [0.12059059 0.87940941 0.         0.         0.         0.        ]
#  [0.35001583 0.64998417 0.         0.         0.         0.        ]
#  [0.98004301 0.01995699 0.         0.         0.         0.        ]]
# [[0.98719263 0.01280737 0.         0.         0.83890317 0.16109683]
#  [0.09811514 0.90188486 0.         0.         0.         0.        ]
#  [0.00143316 0.99856684 0.         0.         0.         1.        ]
#  ...
#  [0.91095475 0.08904525 0.         0.         0.83890317 0.16109683]
#  [0.88861524 0.11138476 1.         0.         0.         0.        ]
#  [0.53509781 0.46490219 0.         0.         1.         0.        ]]

# %%
cv = ShuffleSplit(n_splits=10, test_size=0.3, random_state=0)

model = LogisticRegression(solver='liblinear', max_iter=400, penalty='l2', random_state=0)
# scores = cross_val_score(model, train_X, train_y, cv=cv, scoring='f1_micro')
# scores.mean()

#train_y.fillna(0,inplace=True)

# %%
model.fit(train_X, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=400,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# val_scores = cross_val_score(model, val_X, val_y, cv=cv, scoring='f1_micro')
# val_scores.mean()

# %%
#val_predictions = model.predict(val_X)

# %%
#f1_score(val_y, val_predictions, average='micro')
# Out:
# 0.9845794392523365

# %%
# test_scores = cross_val_score(model, test_X, test_y, cv=cv, scoring='f1_micro')
# test_scores.mean()

# %%
test_predictions = model.predict(test_X)

# %%
f1_score(test_y, test_predictions, average='micro')
# Out:
# 0.9299065420560748

# %%
 precision_score(train_y, test_predictions)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1305: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if pos_label not in present_labels:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-18b3aa552f8d> in <module>()
# ----> 1 precision_score(train_y, test_predictions)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1670                                                  warn_for=('precision',),
#    1671                                                  sample_weight=sample_weight,
# -> 1672                                                  zero_division=zero_division)
#    1673     return p
#    1674
#
# ...

# %%
accuracy_score(test_y,test_predictions)
# Out:
# 0.5141744548286604
